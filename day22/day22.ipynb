# %% [markdown]
# # Pandas Profiling

# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (2.10.3)
# Collecting PyYAML<6.1,>=6.0.3 (from ydata-profiling)
#   Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (2.1.3)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling)
#   Downloading phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (0.14.4)
# Collecting typeguard<5,>=4 (from ydata-profiling)
#   Downloading typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.2 (from ydata-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling)
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\akshay\anaconda3\lib\site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in c:\users\akshay\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\akshay\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\akshay\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akshay\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\akshay\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akshay\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akshay\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\akshay\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akshay\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akshay\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\akshay\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akshay\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\akshay\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\akshay\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\akshay\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\akshay\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\akshay\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akshay\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshay\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshay\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshay\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\akshay\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\akshay\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Collecting typing-extensions>=4.12.2 (from pydantic<3,>=2->ydata-profiling)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\akshay\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\akshay\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-2.0.2-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\akshay\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 678.1/678.1 kB 5.6 MB/s eta 0:00:00
# Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --------------------------------- ------ 2.6/3.1 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 12.3 MB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Downloading puremagic-2.0.2-py3-none-any.whl (65 kB)
# Installing collected packages: minify-html, filetype, typing-extensions, PyYAML, puremagic, multimethod, dacite, typeguard, imagehash, wordcloud, visions, phik, ydata-profiling
#
#    --- ------------------------------------  1/13 [filetype]
#   Attempting uninstall: typing-extensions
#    --- ------------------------------------  1/13 [filetype]
#     Found existing installation: typing_extensions 4.12.2
#    --- ------------------------------------  1/13 [filetype]
#     Uninstalling typing_extensions-4.12.2:
#    --- ------------------------------------  1/13 [filetype]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#   Attempting uninstall: PyYAML
#    ------ ---------------------------------  2/13 [typing-extensions]
#     Found existing installation: PyYAML 6.0.2
#    ------ ---------------------------------  2/13 [typing-extensions]
#     Uninstalling PyYAML-6.0.2:
#    ------ ---------------------------------  2/13 [typing-extensions]
#    --------- ------------------------------  3/13 [PyYAML]
#       Successfully uninstalled PyYAML-6.0.2
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    ------------ ---------------------------  4/13 [puremagic]
#    ------------------ ---------------------  6/13 [dacite]
#    ------------------------ ---------------  8/13 [imagehash]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    --------------------------------- ------ 11/13 [phik]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ---------------------------------------- 13/13 [ydata-profiling]
#
# Successfully installed PyYAML-6.0.3 dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-2.0.2 typeguard-4.5.1 typing-extensions-4.15.0 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Akshay\anaconda3\Lib\site-packages\~aml'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 6.0.7 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 9.4.0 which is incompatible.

# %%
from ydata_profiling import ProfileReport

# %%
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 85.40it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
